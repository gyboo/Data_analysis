# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['font.sans-serif'] = ['FangSong']
mpl.rcParams['axes.unicode_minus'] = False

from IPython.display import display
df = pd.read_excel("D:datasets\mldata\data1.xlsx",index_col='ID')
df.head(8)
# Out:
#                          title                     tag1  \
# ID
# 1665E                MinimizOR                 bitmasks
# 1665D                GCD Guess                 bitmasks
# 1665C           Tree Infection            binary search
# 1665B  Array Cloning Technique  constructive algorithms
# 1665A               GCD vs LCM  constructive algorithms
# 1663H   Cross-Language Program  constructive algorithms
# 1663G           Six Characters  constructive algorithms
# 1663F   In Every Generation...                  strings
#
#                           tag2  score   Accept
# ID
# 1665E          data structures    NaN    392.0
# 1665D  constructive algorithms    NaN   1371.0
# 1665C  constructive algorithms    NaN   3086.0
# 1665B                   greedy    NaN  10305.0
# 1665A                     math    NaN  13346.0
# 1663H                      NaN    NaN    907.0
# 1663G                  strings    NaN     82.0
# 1663F                      NaN    NaN    182.0

# %%
df.shape
# Out:
# (1100, 5)

# %%
col = (df['score']>0) & (df['Accept']>0)
df = df[col]
df.shape
# Out:
# (1051, 5)

# %%
df['count'] = df['tag2'].isnull() + df['tag1'].isnull()
df.head(10)
# Out:
#                                   title             tag1  \
# ID
# 1660F2  Promising String (hard version)  data structures
# 1660F1  Promising String (easy version)      brute force
# 1660E                 Matrix and Shifts      brute force
# 1660D      Maximum Product Strikes Back      brute force
# 1660C                Get an Even String               dp
# 1660B                  Vlad and Candies             math
# 1660A                   Vasya and Coins           greedy
# 1658F            Juju and Binary String      brute force
# 1658E             Gojou and Matrix Game  data structures
# 1658D2            388535 (Hard Version)         bitmasks
#
#                            tag2   score   Accept  count
# ID
# 1660F2           implementation  2100.0   1430.0  False
# 1660F1           implementation  1700.0   4277.0  False
# 1660E   constructive algorithms  1600.0   3930.0  False
# 1660D            implementation  1600.0   4534.0  False
# ...

# %%
df['count'] = df['count'].apply(lambda x:2 if x == False else 1)
df.head()
# Out:
#                                   title             tag1  \
# ID
# 1660F2  Promising String (hard version)  data structures
# 1660F1  Promising String (easy version)      brute force
# 1660E                 Matrix and Shifts      brute force
# 1660D      Maximum Product Strikes Back      brute force
# 1660C                Get an Even String               dp
#
#                            tag2   score   Accept  count
# ID
# 1660F2           implementation  2100.0   1430.0      2
# 1660F1           implementation  1700.0   4277.0      2
# 1660E   constructive algorithms  1600.0   3930.0      2
# 1660D            implementation  1600.0   4534.0      2
# 1660C                    greedy  1300.0  10771.0      2

# %%
t = df.index


index = []
for it in t:
    if(type(it) == int):
        if(it % 1000 == 0):
            index.append('E3')
        elif(it % 100 == 0):
            index.append('E2')
        elif(it % 10 == 0):
            index.append('E1')
    else:
        index.append(it[4:])
index
# Out:
# ['F2',
#  'F1',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D2',
#  'D1',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'I',
#  'H',
#  'G',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'H',
#  'G',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'G',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'H',
#  'G',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'F',
#  'E',
#  'D',
#  'C',
#  'B',
#  'A',
#  'E2',
#  'E1',
#  'D',
#  'C',
#  'B',
#  'A',
#  'B',
#  'A',
# ...

# %%
df['letter'] = index
df.head()
# Out:
#                                   title             tag1  \
# ID
# 1660F2  Promising String (hard version)  data structures
# 1660F1  Promising String (easy version)      brute force
# 1660E                 Matrix and Shifts      brute force
# 1660D      Maximum Product Strikes Back      brute force
# 1660C                Get an Even String               dp
#
#                            tag2   score   Accept  count letter
# ID
# 1660F2           implementation  2100.0   1430.0      2     F2
# 1660F1           implementation  1700.0   4277.0      2     F1
# 1660E   constructive algorithms  1600.0   3930.0      2      E
# 1660D            implementation  1600.0   4534.0      2      D
# 1660C                    greedy  1300.0  10771.0      2      C

# %%
df = df.iloc[::-1]
df.head()
# Out:
#                      title                     tag1                     tag2  \
# ID
# 1453C            Triangles                   greedy           implementation
# 1453D          Checkpoints              brute force  constructive algorithms
# 1453E           Dog Snacks            binary search          dfs and similar
# 1453F          Even Harder                       dp                      NaN
# 1454A  Special Permutation  constructive algorithms            probabilities
#
#         score   Accept  count
# ID
# 1453C  1700.0   5377.0      2
# 1453D  1900.0   3569.0      2
# 1453E  2300.0   1670.0      2
# 1453F  2700.0    578.0      1
# 1454A   800.0  30780.0      2

# %%
ds = df.describe()
ds
# Out:
#              score       Accept        count
# count  1051.000000   1088.00000  1100.000000
# mean   1888.296860   7418.90625     1.903636
# std     802.001099   8024.07045     0.295224
# min     800.000000      6.00000     1.000000
# 25%    1200.000000    623.75000     2.000000
# 50%    1800.000000   3677.00000     2.000000
# 75%    2500.000000  12827.00000     2.000000
# max    3500.000000  36041.00000     2.000000

# %%
X = df[['score','count']]
y = np.array(df['Accept']).reshape(-1,1)
print(X.shape)
print(y.shape)
# Out:
# (1051, 2)
# (1051, 1)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

mi = 3e8
mi_state = 1
for i in range(0,200):
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=i) #求最好的随机种子


    gnb = Pipeline([
    ("poly", PolynomialFeatures(degree=4)),
    ("std_scaler", StandardScaler()),
    ("lin_reg", LinearRegression())
    ])
    gnb.fit(X_train,y_train)
    y_predict = gnb.predict(X_test)
    mse_test = np.sum((y_predict - y_test)**2) / len(y_test) #根据mse判断
    #print(mse_test)
    if(mse_test < mi):
        mi = mse_test
        mi_state = i
print(mi)
print(mi_state)
# Out:
# 4376142.285747612
# 76

# %%
#4 4376142

# %%
print(X.shape)
print(y.shape)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=76)


reg=Pipeline([  
    ("poly", PolynomialFeatures(degree=4)), #多项式
    ("std_scaler", StandardScaler()), #标准化
    ("lin_reg", LinearRegression()) #线性回归
    ])

reg.fit(X_train,y_train)
y_predict = reg.predict(X_test)

plt.figure(figsize = (20, 8)) # 设置图像大小
plt.plot(range(0,y_test.size), reg.predict(X_test), color='r', marker='o')
plt.plot(range(0,y_test.size), y_test, color='b', marker='.')
plt.show()
# Out:
# (1051, 2)
# (1051, 1)

# %%
# print(df['tag1'].value_counts())

fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot(111)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.barh(df['tag1'].value_counts().index,df['tag1'].value_counts())

fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot(111)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.barh(df['tag2'].value_counts().index,df['tag2'].value_counts())
# Out:
# <BarContainer object of 31 artists>

# %%
# print(df['tag1'].value_counts())

plt.figure(figsize = (20,18))
plt.subplot(211)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.barh(df['tag1'].value_counts().index,df['tag1'].value_counts())

plt.subplot(212)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.barh(df['tag2'].value_counts().index,df['tag2'].value_counts())
plt.show()

# %%
#!/usr/bin/python
#coding: utf-8
 
import numpy as np
import matplotlib.pyplot as plt
 
x = np.arange(0, 100)
 
fig = plt.figure()
 
ax1 = fig.add_subplot(221) #面向对象
ax1.plot(x, x)
 
ax2 = fig.add_subplot(222)
ax2.plot(x, -x)
 
ax3 = fig.add_subplot(223)
ax3.plot(x, x ** 2)
 
ax4 = fig.add_subplot(224)
ax4.plot(x, np.log(x))
 
plt.show()
# Out:
# C:\Users\26792\AppData\Local\Temp/ipykernel_19064/2943195298.py:21: RuntimeWarning: divide by zero encountered in log
#   ax4.plot(x, np.log(x))

# %%
#!/usr/bin/python
#coding: utf-8
 
import numpy as np
import matplotlib.pyplot as plt
 
x = np.arange(0, 100)
 
plt.subplot(221)
plt.plot(x, x)
 
plt.subplot(222)
plt.plot(x, -x)
 
plt.subplot(223)
plt.plot(x, x ** 2)
 
plt.subplot(224)
plt.plot(x, np.log(x))
 
plt.show()
# Out:
# C:\Users\26792\AppData\Local\Temp/ipykernel_19064/1864222241.py:19: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, np.log(x))

# %%
df.corr()
# Out:
#            score    Accept
# score   1.000000 -0.858032
# Accept -0.858032  1.000000

# %%
df.corr(method='spearman')
# Out:
#            score    Accept
# score   1.000000 -0.961382
# Accept -0.961382  1.000000

# %%
df.corr(method='kendall')
# Out:
#            score    Accept
# score   1.000000 -0.859041
# Accept -0.859041  1.000000

# %%
test1 = df[['Accept','score']].head(20)
test1.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='ID'>

# %%
ax=plt.subplots(figsize=(20,16))
ax=sns.heatmap(corr,vmax=.8,square=True,annot=True)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([0.5, 1.5]), [Text(0, 0.5, 'score'), Text(0, 1.5, 'Accept')])
